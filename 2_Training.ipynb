# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** The Encoder (CNN) is using the layers of a ResNet50 just to extract features of the image. The last layer was cropped and replaced by a brand new fully connected layer, on the same size of the embedding layer that will receive the words. This layer will be trained in conjunction with the Decoder.
#
# The Decoder (RNN) is an extremely simple RNN network with a LSTM layer at the core and one embedding layer at the input. The embbeding layer will receive the linear layer from the decoder as first input, and on next steps the embedding of the words on the sentence, one word per step. The output will receive the next word.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# Since I am using a pretrained network, the transform need to be the same that was applied on the original training of the network.
#
# **Answer:**
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
#
# Since we are not using pretrained word embeddings, we need to learn the embeddings and the LSTM weights. Another option was to use pretrained word embeddings on input and output of the RNN, or a Vectorizer like BoWVEctorizer or HashingVectorizer. Most modern networks embed words and sentences with big word embeddings and attention mechanisms, using bidirectional LSTM networks, but these networks need a lot of memory and computional resources.
#
# Using Occam Razor's reasoning, it is better to start with simplest solution and see if it fits.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**  The optimizer chosen was Adam, because normally it needs less learning rate tuning and on my hardware the training was tooking more than 4 hours for each epoch.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('./cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 256          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file,
                        cocoapi_loc='.')

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters()) 

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params = params, lr = 0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# loading annotations into memory...
# Done (t=1.48s)
# creating index...
# index created!
# [0/414113] Tokenizing captions...
# [100000/414113] Tokenizing captions...
# [200000/414113] Tokenizing captions...
# [300000/414113] Tokenizing captions...
# [400000/414113] Tokenizing captions...
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:36<00:00, 11392.44it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
#import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
#response = requests.request("GET", 
#                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
#                            headers={"Metadata-Flavor":"Google"})

for epoch in range(2, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
        #    requests.request("POST", 
        #                     "https://nebula.udacity.com/api/v1/remote/keep-alive", 
        #                     headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [2/3], Step [100/12942], Loss: 2.4640, Perplexity: 11.7515
# Epoch [2/3], Step [200/12942], Loss: 2.0218, Perplexity: 7.55166
# Epoch [2/3], Step [300/12942], Loss: 2.2272, Perplexity: 9.274180
# Epoch [2/3], Step [400/12942], Loss: 2.0165, Perplexity: 7.51174
# Epoch [2/3], Step [500/12942], Loss: 2.5366, Perplexity: 12.6366
# Epoch [2/3], Step [600/12942], Loss: 2.1727, Perplexity: 8.78210
# Epoch [2/3], Step [700/12942], Loss: 1.9860, Perplexity: 7.28616
# Epoch [2/3], Step [800/12942], Loss: 2.3695, Perplexity: 10.6919
# Epoch [2/3], Step [900/12942], Loss: 2.6448, Perplexity: 14.0801
# Epoch [2/3], Step [1000/12942], Loss: 1.8536, Perplexity: 6.3830
# Epoch [2/3], Step [1100/12942], Loss: 2.1663, Perplexity: 8.72585
# Epoch [2/3], Step [1200/12942], Loss: 2.0901, Perplexity: 8.08589
# Epoch [2/3], Step [1300/12942], Loss: 2.1405, Perplexity: 8.50388
# Epoch [2/3], Step [1400/12942], Loss: 2.1693, Perplexity: 8.75213
# Epoch [2/3], Step [1500/12942], Loss: 2.4846, Perplexity: 11.9958
# Epoch [2/3], Step [1600/12942], Loss: 2.1678, Perplexity: 8.73936
# Epoch [2/3], Step [1700/12942], Loss: 2.9987, Perplexity: 20.0595
# Epoch [2/3], Step [1800/12942], Loss: 2.2403, Perplexity: 9.39587
# Epoch [2/3], Step [1900/12942], Loss: 2.1811, Perplexity: 8.85627
# Epoch [2/3], Step [2000/12942], Loss: 2.0818, Perplexity: 8.01889
# Epoch [2/3], Step [2100/12942], Loss: 2.0659, Perplexity: 7.89222
# Epoch [2/3], Step [2200/12942], Loss: 2.3164, Perplexity: 10.1395
# Epoch [2/3], Step [2300/12942], Loss: 2.2259, Perplexity: 9.26186
# Epoch [2/3], Step [2400/12942], Loss: 2.0066, Perplexity: 7.43775
# Epoch [2/3], Step [2500/12942], Loss: 2.4823, Perplexity: 11.9683
# Epoch [2/3], Step [2600/12942], Loss: 2.0834, Perplexity: 8.03214
# Epoch [2/3], Step [2700/12942], Loss: 2.4353, Perplexity: 11.4194
# Epoch [2/3], Step [2800/12942], Loss: 2.2843, Perplexity: 9.81881
# Epoch [2/3], Step [2900/12942], Loss: 2.0398, Perplexity: 7.68891
# Epoch [2/3], Step [3000/12942], Loss: 1.9925, Perplexity: 7.33416
# Epoch [2/3], Step [3100/12942], Loss: 2.0929, Perplexity: 8.10830
# Epoch [2/3], Step [3200/12942], Loss: 2.0745, Perplexity: 7.96083
# Epoch [2/3], Step [3300/12942], Loss: 2.4318, Perplexity: 11.3797
# Epoch [2/3], Step [3400/12942], Loss: 2.1219, Perplexity: 8.34699
# Epoch [2/3], Step [3500/12942], Loss: 2.2001, Perplexity: 9.02587
# Epoch [2/3], Step [3600/12942], Loss: 1.9786, Perplexity: 7.23292
# Epoch [2/3], Step [3700/12942], Loss: 2.5093, Perplexity: 12.2964
# Epoch [2/3], Step [3800/12942], Loss: 2.1750, Perplexity: 8.80201
# Epoch [2/3], Step [3900/12942], Loss: 2.3993, Perplexity: 11.0158
# Epoch [2/3], Step [4000/12942], Loss: 1.7422, Perplexity: 5.70975
# Epoch [2/3], Step [4100/12942], Loss: 2.4443, Perplexity: 11.5220
# Epoch [2/3], Step [4200/12942], Loss: 2.5365, Perplexity: 12.6359
# Epoch [2/3], Step [4300/12942], Loss: 2.0810, Perplexity: 8.01248
# Epoch [2/3], Step [4400/12942], Loss: 2.3890, Perplexity: 10.9022
# Epoch [2/3], Step [4500/12942], Loss: 2.3425, Perplexity: 10.4075
# Epoch [2/3], Step [4600/12942], Loss: 2.1968, Perplexity: 8.99616
# Epoch [2/3], Step [4700/12942], Loss: 2.5471, Perplexity: 12.7705
# Epoch [2/3], Step [4800/12942], Loss: 2.3966, Perplexity: 10.9852
# Epoch [2/3], Step [4900/12942], Loss: 2.4611, Perplexity: 11.7175
# Epoch [2/3], Step [5000/12942], Loss: 2.4067, Perplexity: 11.0975
# Epoch [2/3], Step [5100/12942], Loss: 2.0857, Perplexity: 8.05014
# Epoch [2/3], Step [5200/12942], Loss: 1.9141, Perplexity: 6.78116
# Epoch [2/3], Step [5300/12942], Loss: 2.1548, Perplexity: 8.62646
# Epoch [2/3], Step [5400/12942], Loss: 2.2562, Perplexity: 9.54716
# Epoch [2/3], Step [5500/12942], Loss: 2.1748, Perplexity: 8.80048
# Epoch [2/3], Step [5600/12942], Loss: 2.1623, Perplexity: 8.69102
# Epoch [2/3], Step [5700/12942], Loss: 2.7454, Perplexity: 15.5709
# Epoch [2/3], Step [5800/12942], Loss: 2.0234, Perplexity: 7.56423
# Epoch [2/3], Step [5900/12942], Loss: 2.2833, Perplexity: 9.80943
# Epoch [2/3], Step [6000/12942], Loss: 2.1593, Perplexity: 8.66503
# Epoch [2/3], Step [6100/12942], Loss: 2.1009, Perplexity: 8.17358
# Epoch [2/3], Step [6200/12942], Loss: 2.3011, Perplexity: 9.98540
# Epoch [2/3], Step [6300/12942], Loss: 2.5142, Perplexity: 12.3565
# Epoch [2/3], Step [6400/12942], Loss: 2.4991, Perplexity: 12.1718
# Epoch [2/3], Step [6500/12942], Loss: 2.4479, Perplexity: 11.5640
# Epoch [2/3], Step [6600/12942], Loss: 2.0741, Perplexity: 7.95716
# Epoch [2/3], Step [6700/12942], Loss: 2.0672, Perplexity: 7.90245
# Epoch [2/3], Step [6800/12942], Loss: 2.3389, Perplexity: 10.3702
# Epoch [2/3], Step [6900/12942], Loss: 2.1861, Perplexity: 8.90069
# Epoch [2/3], Step [7000/12942], Loss: 1.7823, Perplexity: 5.94347
# Epoch [2/3], Step [7100/12942], Loss: 2.2747, Perplexity: 9.72450
# Epoch [2/3], Step [7200/12942], Loss: 1.9410, Perplexity: 6.96551
# Epoch [2/3], Step [7300/12942], Loss: 2.3210, Perplexity: 10.1860
# Epoch [2/3], Step [7400/12942], Loss: 2.4701, Perplexity: 11.8238
# Epoch [2/3], Step [7500/12942], Loss: 2.2389, Perplexity: 9.38300
# Epoch [2/3], Step [7600/12942], Loss: 2.0826, Perplexity: 8.02513
# Epoch [2/3], Step [7700/12942], Loss: 2.2112, Perplexity: 9.12698
# Epoch [2/3], Step [7800/12942], Loss: 2.0771, Perplexity: 7.98142
# Epoch [2/3], Step [7900/12942], Loss: 2.1317, Perplexity: 8.42934
# Epoch [2/3], Step [8000/12942], Loss: 2.3310, Perplexity: 10.2884
# Epoch [2/3], Step [8100/12942], Loss: 2.1356, Perplexity: 8.46240
# Epoch [2/3], Step [8200/12942], Loss: 2.1693, Perplexity: 8.75189
# Epoch [2/3], Step [8300/12942], Loss: 2.2279, Perplexity: 9.28002
# Epoch [2/3], Step [8400/12942], Loss: 2.2908, Perplexity: 9.88247
# Epoch [2/3], Step [8500/12942], Loss: 2.0048, Perplexity: 7.42461
# Epoch [2/3], Step [8600/12942], Loss: 2.1964, Perplexity: 8.99299
# Epoch [2/3], Step [8700/12942], Loss: 2.1744, Perplexity: 8.79680
# Epoch [2/3], Step [8800/12942], Loss: 1.9247, Perplexity: 6.85309
# Epoch [2/3], Step [8900/12942], Loss: 2.0203, Perplexity: 7.54034
# Epoch [2/3], Step [9000/12942], Loss: 2.0275, Perplexity: 7.59536
# Epoch [2/3], Step [9100/12942], Loss: 2.3810, Perplexity: 10.8158
# Epoch [2/3], Step [9200/12942], Loss: 2.3242, Perplexity: 10.2189
# Epoch [2/3], Step [9300/12942], Loss: 1.9760, Perplexity: 7.21396
# Epoch [2/3], Step [9400/12942], Loss: 2.1217, Perplexity: 8.34504
# Epoch [2/3], Step [9500/12942], Loss: 2.0003, Perplexity: 7.39141
# Epoch [2/3], Step [9600/12942], Loss: 2.0454, Perplexity: 7.73205
# Epoch [2/3], Step [9700/12942], Loss: 2.2533, Perplexity: 9.51926
# Epoch [2/3], Step [9800/12942], Loss: 2.1489, Perplexity: 8.57533
# Epoch [2/3], Step [9900/12942], Loss: 2.8443, Perplexity: 17.1904
# Epoch [2/3], Step [10000/12942], Loss: 2.0193, Perplexity: 7.5330
# Epoch [2/3], Step [10100/12942], Loss: 2.3898, Perplexity: 10.9110
# Epoch [2/3], Step [10200/12942], Loss: 1.9545, Perplexity: 7.06077
# Epoch [2/3], Step [10300/12942], Loss: 2.0148, Perplexity: 7.49905
# Epoch [2/3], Step [10400/12942], Loss: 2.0566, Perplexity: 7.81907
# Epoch [2/3], Step [10500/12942], Loss: 2.1289, Perplexity: 8.40573
# Epoch [2/3], Step [10600/12942], Loss: 2.3724, Perplexity: 10.7231
# Epoch [2/3], Step [10700/12942], Loss: 2.4959, Perplexity: 12.1332
# Epoch [2/3], Step [10800/12942], Loss: 2.2985, Perplexity: 9.95909
# Epoch [2/3], Step [10900/12942], Loss: 2.5033, Perplexity: 12.2225
# Epoch [2/3], Step [11000/12942], Loss: 1.8799, Perplexity: 6.55300
# Epoch [2/3], Step [11100/12942], Loss: 2.2651, Perplexity: 9.63180
# Epoch [2/3], Step [11200/12942], Loss: 2.0685, Perplexity: 7.91292
# Epoch [2/3], Step [11300/12942], Loss: 2.0290, Perplexity: 7.60628
# Epoch [2/3], Step [11400/12942], Loss: 2.3347, Perplexity: 10.3262
# Epoch [2/3], Step [11500/12942], Loss: 2.1370, Perplexity: 8.47361
# Epoch [2/3], Step [11600/12942], Loss: 2.3534, Perplexity: 10.5210
# Epoch [2/3], Step [11700/12942], Loss: 2.1144, Perplexity: 8.28443
# Epoch [2/3], Step [11800/12942], Loss: 2.4052, Perplexity: 11.0807
# Epoch [2/3], Step [11900/12942], Loss: 1.9809, Perplexity: 7.24922
# Epoch [2/3], Step [12000/12942], Loss: 2.0729, Perplexity: 7.94795
# Epoch [2/3], Step [12100/12942], Loss: 2.7574, Perplexity: 15.7582
# Epoch [2/3], Step [12200/12942], Loss: 2.5356, Perplexity: 12.6243
# Epoch [2/3], Step [12300/12942], Loss: 2.1183, Perplexity: 8.31701
# Epoch [2/3], Step [12400/12942], Loss: 2.1284, Perplexity: 8.40151
# Epoch [2/3], Step [12500/12942], Loss: 2.2773, Perplexity: 9.75075
# Epoch [2/3], Step [12600/12942], Loss: 2.4437, Perplexity: 11.5152
# Epoch [2/3], Step [12700/12942], Loss: 1.9326, Perplexity: 6.90759
# Epoch [2/3], Step [12800/12942], Loss: 2.3413, Perplexity: 10.3949
# Epoch [2/3], Step [12900/12942], Loss: 2.1564, Perplexity: 8.63988
# Epoch [3/3], Step [100/12942], Loss: 2.0627, Perplexity: 7.8673442
# Epoch [3/3], Step [200/12942], Loss: 1.8094, Perplexity: 6.10685
# Epoch [3/3], Step [300/12942], Loss: 2.0234, Perplexity: 7.56383
# Epoch [3/3], Step [400/12942], Loss: 2.1571, Perplexity: 8.64638
# Epoch [3/3], Step [500/12942], Loss: 2.2841, Perplexity: 9.81687
# Epoch [3/3], Step [600/12942], Loss: 2.0782, Perplexity: 7.99018
# Epoch [3/3], Step [700/12942], Loss: 2.0397, Perplexity: 7.68793
# Epoch [3/3], Step [800/12942], Loss: 1.9970, Perplexity: 7.36670
# Epoch [3/3], Step [900/12942], Loss: 2.1300, Perplexity: 8.41514
# Epoch [3/3], Step [1000/12942], Loss: 2.0806, Perplexity: 8.0091
# Epoch [3/3], Step [1100/12942], Loss: 2.4604, Perplexity: 11.7100
# Epoch [3/3], Step [1200/12942], Loss: 2.1128, Perplexity: 8.27131
# Epoch [3/3], Step [1300/12942], Loss: 2.3882, Perplexity: 10.8934
# Epoch [3/3], Step [1400/12942], Loss: 2.0893, Perplexity: 8.07912
# Epoch [3/3], Step [1500/12942], Loss: 2.2565, Perplexity: 9.54928
# Epoch [3/3], Step [1600/12942], Loss: 2.6405, Perplexity: 14.0202
# Epoch [3/3], Step [1700/12942], Loss: 2.4744, Perplexity: 11.8747
# Epoch [3/3], Step [1800/12942], Loss: 1.8579, Perplexity: 6.41044
# Epoch [3/3], Step [1900/12942], Loss: 2.1740, Perplexity: 8.79370
# Epoch [3/3], Step [2000/12942], Loss: 1.9795, Perplexity: 7.23954
# Epoch [3/3], Step [2100/12942], Loss: 2.1473, Perplexity: 8.56186
# Epoch [3/3], Step [2200/12942], Loss: 2.1808, Perplexity: 8.85310
# Epoch [3/3], Step [2300/12942], Loss: 2.1360, Perplexity: 8.46586
# Epoch [3/3], Step [2400/12942], Loss: 2.0497, Perplexity: 7.76570
# Epoch [3/3], Step [2500/12942], Loss: 1.8891, Perplexity: 6.61314
# Epoch [3/3], Step [2600/12942], Loss: 2.1146, Perplexity: 8.28668
# Epoch [3/3], Step [2700/12942], Loss: 1.9260, Perplexity: 6.86193
# Epoch [3/3], Step [2800/12942], Loss: 2.6162, Perplexity: 13.6843
# Epoch [3/3], Step [2900/12942], Loss: 2.1495, Perplexity: 8.58040
# Epoch [3/3], Step [3000/12942], Loss: 2.2181, Perplexity: 9.19004
# Epoch [3/3], Step [3100/12942], Loss: 2.2604, Perplexity: 9.58673
# Epoch [3/3], Step [3200/12942], Loss: 2.3107, Perplexity: 10.0815
# Epoch [3/3], Step [3300/12942], Loss: 1.9324, Perplexity: 6.90612
# Epoch [3/3], Step [3400/12942], Loss: 2.2373, Perplexity: 9.36775
# Epoch [3/3], Step [3500/12942], Loss: 1.9470, Perplexity: 7.00758
# Epoch [3/3], Step [3600/12942], Loss: 2.1522, Perplexity: 8.60429
# Epoch [3/3], Step [3700/12942], Loss: 2.3876, Perplexity: 10.8871
# Epoch [3/3], Step [3800/12942], Loss: 1.9161, Perplexity: 6.79444
# Epoch [3/3], Step [3900/12942], Loss: 2.4496, Perplexity: 11.5837
# Epoch [3/3], Step [4000/12942], Loss: 2.0570, Perplexity: 7.82220
# Epoch [3/3], Step [4100/12942], Loss: 1.9269, Perplexity: 6.86810
# Epoch [3/3], Step [4200/12942], Loss: 1.9915, Perplexity: 7.32639
# Epoch [3/3], Step [4300/12942], Loss: 1.8833, Perplexity: 6.57547
# Epoch [3/3], Step [4400/12942], Loss: 2.1181, Perplexity: 8.31505
# Epoch [3/3], Step [4500/12942], Loss: 2.1523, Perplexity: 8.60465
# Epoch [3/3], Step [4600/12942], Loss: 2.0499, Perplexity: 7.76685
# Epoch [3/3], Step [4700/12942], Loss: 1.9198, Perplexity: 6.81989
# Epoch [3/3], Step [4800/12942], Loss: 1.9962, Perplexity: 7.36080
# Epoch [3/3], Step [4900/12942], Loss: 2.2205, Perplexity: 9.21214
# Epoch [3/3], Step [5000/12942], Loss: 2.4416, Perplexity: 11.4916
# Epoch [3/3], Step [5100/12942], Loss: 1.9316, Perplexity: 6.90062
# Epoch [3/3], Step [5200/12942], Loss: 2.0465, Perplexity: 7.74086
# Epoch [3/3], Step [5300/12942], Loss: 2.4445, Perplexity: 11.5250
# Epoch [3/3], Step [5400/12942], Loss: 2.1218, Perplexity: 8.34588
# Epoch [3/3], Step [5500/12942], Loss: 1.9908, Perplexity: 7.32168
# Epoch [3/3], Step [5600/12942], Loss: 2.0388, Perplexity: 7.68144
# Epoch [3/3], Step [5700/12942], Loss: 2.2312, Perplexity: 9.31091
# Epoch [3/3], Step [5800/12942], Loss: 2.1827, Perplexity: 8.86990
# Epoch [3/3], Step [5900/12942], Loss: 1.9295, Perplexity: 6.88575
# Epoch [3/3], Step [6000/12942], Loss: 2.2095, Perplexity: 9.11104
# Epoch [3/3], Step [6100/12942], Loss: 2.2507, Perplexity: 9.49426
# Epoch [3/3], Step [6200/12942], Loss: 1.9870, Perplexity: 7.29339
# Epoch [3/3], Step [6300/12942], Loss: 2.4534, Perplexity: 11.6274
# Epoch [3/3], Step [6400/12942], Loss: 2.0331, Perplexity: 7.63783
# Epoch [3/3], Step [6500/12942], Loss: 2.3171, Perplexity: 10.1459
# Epoch [3/3], Step [6600/12942], Loss: 2.1015, Perplexity: 8.17854
# Epoch [3/3], Step [6700/12942], Loss: 1.9226, Perplexity: 6.83897
# Epoch [3/3], Step [6800/12942], Loss: 2.1588, Perplexity: 8.66112
# Epoch [3/3], Step [6900/12942], Loss: 1.9142, Perplexity: 6.78153
# Epoch [3/3], Step [7000/12942], Loss: 2.2199, Perplexity: 9.20609
# Epoch [3/3], Step [7100/12942], Loss: 2.2229, Perplexity: 9.23444
# Epoch [3/3], Step [7200/12942], Loss: 2.1113, Perplexity: 8.25912
# Epoch [3/3], Step [7300/12942], Loss: 2.1156, Perplexity: 8.29430
# Epoch [3/3], Step [7400/12942], Loss: 1.9358, Perplexity: 6.92937
# Epoch [3/3], Step [7500/12942], Loss: 2.0009, Perplexity: 7.39573
# Epoch [3/3], Step [7600/12942], Loss: 2.0637, Perplexity: 7.87541
# Epoch [3/3], Step [7700/12942], Loss: 2.1626, Perplexity: 8.69400
# Epoch [3/3], Step [7800/12942], Loss: 2.4077, Perplexity: 11.1083
# Epoch [3/3], Step [7900/12942], Loss: 2.0888, Perplexity: 8.07495
# Epoch [3/3], Step [8000/12942], Loss: 2.1376, Perplexity: 8.47936
# Epoch [3/3], Step [8100/12942], Loss: 2.0195, Perplexity: 7.53491
# Epoch [3/3], Step [8200/12942], Loss: 2.2483, Perplexity: 9.47211
# Epoch [3/3], Step [8300/12942], Loss: 2.1780, Perplexity: 8.82859
# Epoch [3/3], Step [8400/12942], Loss: 2.2180, Perplexity: 9.18928
# Epoch [3/3], Step [8500/12942], Loss: 1.9920, Perplexity: 7.32986
# Epoch [3/3], Step [8600/12942], Loss: 2.4253, Perplexity: 11.3057
# Epoch [3/3], Step [8700/12942], Loss: 2.2367, Perplexity: 9.36233
# Epoch [3/3], Step [8800/12942], Loss: 2.2858, Perplexity: 9.83400
# Epoch [3/3], Step [8900/12942], Loss: 1.9264, Perplexity: 6.86453
# Epoch [3/3], Step [9000/12942], Loss: 1.9724, Perplexity: 7.18766
# Epoch [3/3], Step [9100/12942], Loss: 1.9223, Perplexity: 6.83691
# Epoch [3/3], Step [9200/12942], Loss: 2.1220, Perplexity: 8.34804
# Epoch [3/3], Step [9300/12942], Loss: 2.0814, Perplexity: 8.015911
# Epoch [3/3], Step [9400/12942], Loss: 2.0819, Perplexity: 8.01941
# Epoch [3/3], Step [9500/12942], Loss: 2.3464, Perplexity: 10.4483
# Epoch [3/3], Step [9600/12942], Loss: 2.0468, Perplexity: 7.74343
# Epoch [3/3], Step [9700/12942], Loss: 2.1392, Perplexity: 8.49266
# Epoch [3/3], Step [9800/12942], Loss: 2.1036, Perplexity: 8.19606
# Epoch [3/3], Step [9900/12942], Loss: 1.8319, Perplexity: 6.24558
# Epoch [3/3], Step [10000/12942], Loss: 1.9607, Perplexity: 7.1044
# Epoch [3/3], Step [10100/12942], Loss: 2.2719, Perplexity: 9.69786
# Epoch [3/3], Step [10200/12942], Loss: 2.1978, Perplexity: 9.00519
# Epoch [3/3], Step [10300/12942], Loss: 1.9779, Perplexity: 7.22742
# Epoch [3/3], Step [10400/12942], Loss: 1.9198, Perplexity: 6.81958
# Epoch [3/3], Step [10500/12942], Loss: 1.8956, Perplexity: 6.65648
# Epoch [3/3], Step [10600/12942], Loss: 1.8431, Perplexity: 6.31592
# Epoch [3/3], Step [10700/12942], Loss: 1.8442, Perplexity: 6.32274
# Epoch [3/3], Step [10800/12942], Loss: 1.8399, Perplexity: 6.29582
# Epoch [3/3], Step [10900/12942], Loss: 2.2279, Perplexity: 9.28062
# Epoch [3/3], Step [11000/12942], Loss: 2.1310, Perplexity: 8.42363
# Epoch [3/3], Step [11100/12942], Loss: 1.9394, Perplexity: 6.95482
# Epoch [3/3], Step [11200/12942], Loss: 2.1145, Perplexity: 8.28550
# Epoch [3/3], Step [11300/12942], Loss: 1.8783, Perplexity: 6.54255
# Epoch [3/3], Step [11400/12942], Loss: 2.1126, Perplexity: 8.26945
# Epoch [3/3], Step [11500/12942], Loss: 2.2515, Perplexity: 9.50179
# Epoch [3/3], Step [11600/12942], Loss: 1.9684, Perplexity: 7.15922
# Epoch [3/3], Step [11700/12942], Loss: 2.0176, Perplexity: 7.52027
# Epoch [3/3], Step [11800/12942], Loss: 1.9548, Perplexity: 7.06224
# Epoch [3/3], Step [11900/12942], Loss: 1.8836, Perplexity: 6.57687
# Epoch [3/3], Step [12000/12942], Loss: 2.2024, Perplexity: 9.04661
# Epoch [3/3], Step [12100/12942], Loss: 2.1498, Perplexity: 8.58288
# Epoch [3/3], Step [12200/12942], Loss: 2.1343, Perplexity: 8.45116
# Epoch [3/3], Step [12300/12942], Loss: 2.1422, Perplexity: 8.51798
# Epoch [3/3], Step [12400/12942], Loss: 2.1449, Perplexity: 8.54093
# Epoch [3/3], Step [12500/12942], Loss: 2.1527, Perplexity: 8.60815
# Epoch [3/3], Step [12600/12942], Loss: 2.0170, Perplexity: 7.51562
# Epoch [3/3], Step [12700/12942], Loss: 2.0304, Perplexity: 7.61758
# Epoch [3/3], Step [12800/12942], Loss: 1.9975, Perplexity: 7.37035
# Epoch [3/3], Step [12900/12942], Loss: 2.1785, Perplexity: 8.83349
# Epoch [3/3], Step [12942/12942], Loss: 2.2985, Perplexity: 9.95970

# %%
torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
